# %%
import pyodbc
import pandas as pd
import os
import vk as vk_lib
import pandas as pd
from time import sleep
import sys
from dotmap import DotMap
import time

# %%
vk = DotMap()
vk.ID = 6302346 
vk.redirect_uri='https://oauth.vk.com/blank.html'
vk.scope='friends,photos,audio,video,docs,notes,pages,status,wall,groups,messages,notifications,offline'
vk.access_token='946dc8a1a740af9ebbbe62ecdd40af070b05d44828226dad5136cef4166057c22b935ebee922ad2426b39'
vk.user_id=215762574
vk.session = vk_lib.Session(access_token=vk.access_token)
vk.api = vk_lib.API(vk.session)
vk.api.users.get(v=3.0)
fields_list=['nickname', 'domain', 'sex', 'bdate', 'city', 'country', 'timezone', 'photo_50',
             'has_mobile', 'contacts', 'education','universities','followers_count','home_town'
            ,'exports']
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# ~\AppData\Local\Continuum\miniconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     440             try:
# --> 441                 cnx.do_handshake()
#     442             except OpenSSL.SSL.WantReadError:
#
# ~\AppData\Local\Continuum\miniconda3\lib\site-packages\OpenSSL\SSL.py in do_handshake(self)
#    1805         result = _lib.SSL_do_handshake(self._ssl)
# -> 1806         self._raise_ssl_error(self._ssl, result)
#    1807
#
# ~\AppData\Local\Continuum\miniconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1545         else:
# -> 1546             _raise_current_error()
#    1547
#
# ...

# %% [markdown]
# # create columns

# %%
res_g_columns = ['bdate', 'can_post', 'city', 'country', 'deactivated', 'domain',
       'education_form', 'education_status', 'facebook', 'facebook_name',
       'faculty', 'faculty_name', 'first_name', 'graduation', 'has_mobile',
       'home_phone', 'instagram', 'last_name', 'mobile_phone', 'relation',
       'relation_partner', 'relatives', 'schools', 'sex', 'site', 'skype',
       'twitter', 'uid', 'universities', 'university', 'university_name','full_name','group_id']
res_g = pd.DataFrame(columns = res_g_columns)
fields_list = ['sex', 'bdate', 'city', 'country','lists', 'domain', 'has_mobile',
               'contacts', 'connections', 'site','education', 'universities', 
               'schools', 'can_post','relation', 'relatives']

# %% [markdown]
# # df

# %%
df = pd.read_csv('group_id.csv',encoding='cp1251')
df
# Out:
#             id
# 0    mat.chast
# 1  mergeclubfr
# 2    124305910

# %%
def GetMembers(g_id):
    a = vk.api.groups.getMembers(group_id=g_id,
                                 v=3.0,
                                 fields= fields_list)
    res = pd.DataFrame(a['users'])
    res['full_name'] = res['first_name'] +str(' ') + res['last_name']
    res['group_id'] = str(g_id)
    res_g = res_g.append(res)

# %%
for i in range((df.shape[0])):
    GetMembers(df['id'].iloc[i])
    time.sleep(5)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# ~\AppData\Local\Continuum\miniconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     440             try:
# --> 441                 cnx.do_handshake()
#     442             except OpenSSL.SSL.WantReadError:
#
# ~\AppData\Local\Continuum\miniconda3\lib\site-packages\OpenSSL\SSL.py in do_handshake(self)
#    1805         result = _lib.SSL_do_handshake(self._ssl)
# -> 1806         self._raise_ssl_error(self._ssl, result)
#    1807
#
# ~\AppData\Local\Continuum\miniconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1545         else:
# -> 1546             _raise_current_error()
#    1547
#
# ...

# %%
a = vk.api.groups.getMembers(group_id='mat.chast',v=3.0,fields= fields_list)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# ~\AppData\Local\Continuum\miniconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     440             try:
# --> 441                 cnx.do_handshake()
#     442             except OpenSSL.SSL.WantReadError:
#
# ~\AppData\Local\Continuum\miniconda3\lib\site-packages\OpenSSL\SSL.py in do_handshake(self)
#    1805         result = _lib.SSL_do_handshake(self._ssl)
# -> 1806         self._raise_ssl_error(self._ssl, result)
#    1807
#
# ~\AppData\Local\Continuum\miniconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1545         else:
# -> 1546             _raise_current_error()
#    1547
#
# ...

# %%
#rel_3_level.to_csv('rel_3_level.csv',index=False)
res_g.to_csv('res_g.csv',index=False)
